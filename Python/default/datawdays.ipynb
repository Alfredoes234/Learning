# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Task4A.csv')
df.describe()
df
# Out:
#     Region Code      Region  Property Type  Rooms  Jan-19  Feb-19  Mar-19  \
# 0             1      London       Bungalow      2    0.79    0.92    0.93
# 1             1      London       Bungalow      3    1.11    0.94    0.05
# 2             1      London  Semi-Detached      2    1.12    0.08    0.67
# 3             1      London  Semi-Detached      3    1.03    0.23    0.36
# 4             1      London       Detached      2    1.22    0.27    0.41
# 5             1      London       Detached      3    1.03    0.10    1.02
# 6             1      London       Detached      4    1.01    0.88    0.79
# 7             2     Bristol       Bungalow      2    0.50    0.64    0.17
# 8             2     Bristol       Bungalow      3    0.99    0.59    0.67
# 9             2     Bristol  Semi-Detached      2    0.57    0.42    0.93
# 10            2     Bristol  Semi-Detached      3    0.17    0.59    0.55
# 11            2     Bristol       Detached      2    0.11    0.85    1.29
# ...

# %%
df.info()
df.head()
df[['Jan-19']].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 45 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region Code    56 non-null     int64
#  1   Region         56 non-null     object
#  2   Property Type  56 non-null     object
#  3   Rooms          56 non-null     int64
#  4   Jan-19         56 non-null     float64
#  5   Feb-19         56 non-null     float64
#  6   Mar-19         56 non-null     float64
#  7   Apr-19         56 non-null     float64
#  8   May-19         56 non-null     float64
#  9   Jun-19         56 non-null     float64
#  10  Jul-19         56 non-null     float64
#  11  Aug-19         56 non-null     float64
#  12  Sep-19         56 non-null     float64
#  13  Oct-19         56 non-null     float64
#  14  Nov-19         56 non-null     float64
#  15  Dec-19         56 non-null     float64
#  16  Jan-20         56 non-null     float64
# ...

# %%
strt = input('Start Date: ')
end = input('End date: ')
fun = df.loc[:, strt:end]
fun
plt.hist(fun,bins=16,linewidth=1,edgecolor='k')
# Out:
# (array([[1., 5., 6., 1., 3., 2., 5., 3., 7., 4., 6., 2., 7., 3., 0., 1.],
#         [4., 4., 5., 5., 4., 7., 2., 6., 2., 6., 5., 4., 2., 0., 0., 0.],
#         [3., 2., 2., 6., 8., 4., 5., 3., 7., 4., 2., 6., 1., 1., 0., 2.]]),
#  array([0.01, 0.09, 0.17, 0.25, 0.33, 0.41, 0.49, 0.57, 0.65, 0.73, 0.81,
#         0.89, 0.97, 1.05, 1.13, 1.21, 1.29]),
#  <a list of 3 BarContainer objects>)

# %%
df[['Jan-19']].sum()
df.index.max()
# Out:
# 55

# %%
df.head()
choice =  input('Choose which colum you want data for:\n> ')
dat = df[choice]
plt.hist(dat,bins=16,linewidth=1,edgecolor='k')
plt.xlabel('Values')
plt.ylabel('Recurrences')
plt.title('Distribution of percentage increase by date')
plt.show()
